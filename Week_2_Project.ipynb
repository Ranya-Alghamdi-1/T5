# %% [markdown]
# <a href="https://colab.research.google.com/github/Ranya-Alghamdi-1/T5/blob/main/Week_2_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Weekly Project 2!

# %% [markdown]
# ## Introduction to Road Traffic Accidents (RTA) Dataset
#
# ### Dataset Overview
# The RTA Dataset provides a detailed snapshot of road traffic accidents, capturing a range of data from accident conditions to casualty details. This dataset is essential for analyzing patterns and causes of accidents to improve road safety.
#
# ### Data Characteristics
# - **Entries**: The dataset contains 12,316 entries.
# - **Features**: There are 32 features in the dataset, which include:
#   - `Time`: Time when the accident occurred.
#   - `Day_of_week`: Day of the week.
#   - `Age_band_of_driver`: Age group of the driver involved.
#   - `Sex_of_driver`: Gender of the driver.
#   - `Educational_level`: Educational level of the driver.
#   - `Type_of_vehicle`: Type of vehicle involved in the accident.
#   - `Cause_of_accident`: Reported cause of the accident.
#   - `Accident_severity`: Severity of the accident.
# - **Target Column**: `Accident_severity` is used as the target column for modeling. This feature classifies the severity of each accident.
#
# ### Objective
# Students will use this dataset to apply various data visualization, modeling, and evaluation techniques learned in class. The primary goal is to build models that can accurately predict the severity of accidents and to identify the key factors that contribute to severe accidents.

# %% [markdown]
# ## Import Libraries
# Import all the necessary libraries here. Include libraries for handling data (like pandas), visualization (like matplotlib and seaborn), and modeling (like scikit-learn).

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import sklearn as sk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load Data
# Load the dataset from the provided CSV file into a DataFrame.

# %%
DF1 = pd.read_csv('/content/drive/MyDrive/T5/WEEK 2 Foundmantal to ML/5- Weekly Project-Week2/5- Weekly Project/RTA_Dataset.csv')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Perform EDA to understand the data better. This involves several steps to summarize the main characteristics, uncover patterns, and establish relationships:
# * Find the dataset information and observe the datatypes.
# * Check the shape of the data to understand its structure.
# * View the the data with various functions to get an initial sense of the data.
# * Perform summary statistics on the dataset to grasp central tendencies and variability.
# * Check for duplicated data.
# * Check for null values.
#
# And apply more if needed!

# %%
DF1.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
DF1.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
DF1.info() # To more info about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df_shape = DF1  # Store the shape tuple if needed
DF1 = df_shape  # Restore df to the original DataFrame
DF1.shape
# Out:
# (12316, 32)

# %%
DF1.describe() # Statistical
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
DF1.describe(include='object') # Statistical for object colunms
# Out:
#             Time Day_of_week Age_band_of_driver Sex_of_driver  \
# count      12316       12316              12316         12316
# unique      1074           7                  5             3
# top     15:30:00      Friday              18-30          Male
# freq         120        2041               4271         11437
#
#          Educational_level Vehicle_driver_relation Driving_experience  \
# count                11575                   11737              11487
# unique                   7                       4                  7
# top     Junior high school                Employee             5-10yr
# freq                  7619                    9627               3363
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# count            11366            11834                    8388  ...
# unique              17                4                       6  ...
# top         Automobile            Owner                 Unknown  ...
# ...

# %%
DF1.duplicated().sum() # To check if any duplicated values
# Out:
# 0

# %%
DF1.isnull().sum() # Find the missing values
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %% [markdown]
# ## Data Preprocessing
# Data preprocessing is essential for transforming raw data into a format suitable for further analysis and modeling. Follow these steps to ensure your data is ready for predictive modeling or advanced analytics:
# - **Handling Missing Values**: Replace missing values with appropriate statistics (mean, median, mode) or use more complex imputation techniques.
# - **Normalization/Scaling**: Scale data to a small, specified range like 0 to 1, or transform it to have a mean of zero and a standard deviation of one.
# - **Label Encoding**: Convert categorical text data into model-understandable numbers where the labels are ordered.
# - **One-Hot Encoding**: Use for nominal categorical data where no ordinal relationship exists to transform the data into a binary column for each category. (Be careful not to increase the dimensionality significantly)
# - **Detection and Treatment of Outliers**: Use statistical tests, box plots, or scatter plots to identify outliers and then cap, trim, or use robust methods to reduce the effect of outliers, depending on the context.
# - **Feature Engineering**: Enhance your dataset by creating new features and transforming existing ones. This might involve combining data from different columns, applying transformations, or reducing dimensionality with techniques like PCA to improve model performance.
#
# Consider these steps as a foundation, and feel free to introduce additional preprocessing techniques as needed to address specific characteristics of your dataset.

# %% [markdown]
# # First : Handling with missing values

# %%
# colunm 1 : Educational_level have 741 missing values
DF1['Educational_level'].value_counts()
DF1["Educational_level"].fillna("Unknown" , inplace =True)
# if we don't have any existing Education that's mean they belong to 'Unkown' Education

# %%
# colunm 2 : Vehicle_driver_relation there are 579 missing
DF1['Vehicle_driver_relation'].value_counts()
DF1["Vehicle_driver_relation"].fillna("Unknown" , inplace =True)
# if we don't have any existing relation that's mean they belong to 'Unkown' relation

# %%
# colunm 3: Driving_experience	: 829
DF1['Driving_experience'].value_counts()
DF1['Driving_experience'].mode()
DF1['Driving_experience'] = DF1['Driving_experience'].apply(lambda x: str(x).replace('yr', ''))
DF1['Driving_experience'].unique()
#we need to fix this colunm with there are 2-5yr and no licance and unknown and above of 10 etc....
DF1["Driving_experience"].fillna("5-10" , inplace =True)
DF1['Driving_experience'].value_counts()

# %%
# colunm 4: Type_of_vehicle: 950
#df['Type_of_vehicle'].value_counts()
DF1['Type_of_vehicle'].mode()
DF1["Type_of_vehicle"].fillna("Other", inplace =True)

# %%
# colunm 5 : Owner_of_vehicle:	482
DF1['Owner_of_vehicle'].value_counts()
DF1['Owner_of_vehicle'].fillna(DF1['Owner_of_vehicle'].mode()[0], inplace=True) # اللي هو المالك

# %%
# Colunm 6 : Service_year_of_vehicle	: 3928
#df['Service_year_of_vehicle'].value_counts()
DF1['Service_year_of_vehicle'].mode()
DF1['Service_year_of_vehicle'].fillna(DF1['Service_year_of_vehicle'].mode()[0], inplace=True) # اللي هو غير معروف

# %%
# colunm 7: Defect_of_vehicle	4427
#replace 'no defect' whit 0 then replace the colunm ti int
DF1['Defect_of_vehicle'] = DF1['Defect_of_vehicle'].replace('No defect', 0)
DF1['Defect_of_vehicle'] = DF1['Defect_of_vehicle'].astype(float)
DF1['Defect_of_vehicle'].value_counts()
DF1['Defect_of_vehicle'].fillna(DF1['Defect_of_vehicle'].mode()[0], inplace=True)

# %%
# colunm 8: Area_accident_occured	: 239
DF1['Area_accident_occured'].value_counts()
DF1['Area_accident_occured'].fillna(DF1['Area_accident_occured'].mode()[0], inplace=True)
DF1['Area_accident_occured'].unique()

# %%
# colunm 9: Lanes_or_Medians :385
# There are 'nan' values
DF1['Lanes_or_Medians'].value_counts()
DF1['Lanes_or_Medians'].unique()
DF1['Lanes_or_Medians'] = DF1['Lanes_or_Medians'].replace('nan', np.nan)
DF1['Lanes_or_Medians'] = DF1['Lanes_or_Medians'].fillna('other')
DF1['Lanes_or_Medians'] = DF1['Lanes_or_Medians'].replace('other', np.nan)
DF1['Lanes_or_Medians'].fillna(DF1['Lanes_or_Medians'].mode()[0], inplace=True)

# %%
# colunm 10 : Road_allignment	: 142
# There are 'nan' values
DF1['Road_allignment'].value_counts()
DF1['Road_allignment'].unique()
DF1['Road_allignment'] = DF1['Road_allignment'].replace('nan', np.nan)
DF1['Road_allignment'] = DF1['Road_allignment'].fillna('other')
DF1['Road_allignment'] = DF1['Road_allignment'].replace('other', np.nan)
DF1['Road_allignment'].fillna(DF1['Road_allignment'].mode()[0], inplace=True)

# %%
# colunm 11 : Types_of_Junction	: 887
# There are 'nan' values
DF1['Types_of_Junction'].value_counts()
DF1['Types_of_Junction'].unique()
DF1['Types_of_Junction'] = DF1['Types_of_Junction'].replace('nan', np.nan)
DF1['Types_of_Junction'] = DF1['Types_of_Junction'].fillna('Other')
DF1['Types_of_Junction'] = DF1['Types_of_Junction'].replace('Other', np.nan)
DF1['Types_of_Junction'].fillna(DF1['Types_of_Junction'].mode()[0], inplace=True)

# %%
# colunm 12: Road_surface_type: 172
# There are 'nan' values
DF1['Road_surface_type'].unique()
DF1['Road_surface_type'].value_counts()
DF1['Road_surface_type'] = DF1['Road_surface_type'].replace('nan', np.nan)
DF1['Road_surface_type'] = DF1['Road_surface_type'].fillna('Other')
DF1['Road_surface_type'] = DF1['Road_surface_type'].replace('Other', np.nan)
DF1['Road_surface_type'].fillna(DF1['Road_surface_type'].mode()[0], inplace=True)

# %%
# colunm 13 : Type_of_collision	:155
# There are 'nan' values
DF1['Type_of_collision'].unique()
DF1['Type_of_collision'].value_counts()
DF1['Type_of_collision'] = DF1['Type_of_collision'].replace('nan', np.nan)
DF1['Type_of_collision'] = DF1['Type_of_collision'].fillna('Unkown')
DF1['Type_of_collision'] = DF1['Type_of_collision'].replace('Unknown', np.nan)
DF1['Type_of_collision'].fillna(DF1['Type_of_collision'].mode()[0], inplace=True)

# %%
#colunm 14: Vehicle_movement	308
DF1['Vehicle_movement'].unique() # There are 'nan' values
DF1['Vehicle_movement'].value_counts()
DF1['Vehicle_movement'] = DF1['Vehicle_movement'].replace('nan', np.nan)
DF1['Vehicle_movement'] = DF1['Vehicle_movement'].fillna('Unkown')
DF1['Vehicle_movement'] = DF1['Vehicle_movement'].replace('Unknown', np.nan)
DF1['Vehicle_movement'].fillna(DF1['Vehicle_movement'].mode()[0], inplace=True)

# %%
# colunm 15: Work_of_casuality	: 3198
# There are 'nan' values
DF1['Work_of_casuality'].unique()
#df1['Work_of_casuality'].value_counts()
DF1['Work_of_casuality'] = DF1['Work_of_casuality'].replace('nan', np.nan)
DF1['Work_of_casuality'] = DF1['Work_of_casuality'].fillna('Unkown')
DF1['Work_of_casuality'] = DF1['Work_of_casuality'].replace('Unknown', np.nan)
DF1['Work_of_casuality'].fillna(DF1['Work_of_casuality'].mode()[0], inplace=True)

# %%
# colunm 16: Fitness_of_casuality	: 2635
DF1['Fitness_of_casuality'].value_counts()
#fill with fillforword and backword
DF1['Fitness_of_casuality'] = DF1['Fitness_of_casuality'].fillna(method='ffill')
DF1['Fitness_of_casuality'] = DF1['Fitness_of_casuality'].fillna(method='bfill')

# %%
DF1.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %% [markdown]
# # Second : Normalization/Scaling:

# %% [markdown]
# # Third Label Encoding  & One-Hot Encoding

# %%
DF1.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
'''
# One-Hot Ecnoding
DF1 = pd.get_dummies(DF1, columns=[
    'Sex_of_driver',
    'Weather_conditions',
])

#'Type_of_vehicle',
    #'Sex_of_casualty'
    #'Driving_experience',
    #'Defect_of_vehicle',
'''

# Lable Encoding
label_encoder = LabelEncoder()
label_columns = [
    'Accident_severity', # 3 types
    'Educational_level',
    'Vehicle_driver_relation',
    'Owner_of_vehicle',
    'Casualty_class',
    'Type_of_collision',

]
    #'Age_band_of_driver',
    #'Area_accident_occured',
    #'Lanes_or_Medians',
    #'Road_allignment',
    #'Types_of_Junction',
    #'Road_surface_type',
    #'Road_surface_conditions',
    #'Light_conditions',
    #'Vehicle_movement',
    #'Age_band_of_casualty',
    #'Work_of_casuality',
    # 'Fitness_of_casuality
    #'Casualty_severity',


for column in label_columns:
    DF1[column] = label_encoder.fit_transform(DF1[column])

# %% [markdown]
# # Forth Detection and Treatment of Outliers:

# %%
DF1.describe()
# Out:
#        Educational_level  Vehicle_driver_relation  Owner_of_vehicle  \
# count       12316.000000             12316.000000      12316.000000
# mean            3.268513                 0.474829          2.693975
# std             1.416194                 0.926674          0.877637
# min             0.000000                 0.000000          0.000000
# 25%             2.000000                 0.000000          3.000000
# 50%             4.000000                 0.000000          3.000000
# 75%             4.000000                 0.000000          3.000000
# max             6.000000                 3.000000          3.000000
#
#        Defect_of_vehicle  Type_of_collision  Number_of_vehicles_involved  \
# count       12316.000000       12316.000000                 12316.000000
# mean            0.057811           6.393959                     2.040679
# std             0.610028           2.722167                     0.688790
# ...

# %%
# Create the boxplot to detecting an outliers
sns.boxplot(data=DF1[['Educational_level','Casualty_class',	'Accident_severity']]) # بحدد أعمدة
# Out:
# <Axes: >

# %% [markdown]
# # Fifth Feature Engineering:

# %%
DF1['Driver_Experience_by_Age'] = DF1['Driving_experience'] + '_' + DF1['Age_band_of_driver']
# دمج Age_band_of_driver وDriving_experience فيتشر جديدة تمثل خبرة السائق بالنسبة للعمر.

# %% [markdown]
# ## Data Visualization
# Create various plots to visualize the relationships in the data. Consider using the following to show different aspects of the data:
#
# * Heatmap of Correlation Matrix.
# * Line plots.
# * Scatter plots.
# * Histograms.
# * Boxplots.
#
# Use more if needed!

# %%
#Create a heatmap visualise
sns.heatmap(DF1[[ 'Accident_severity',
    'Educational_level',
    'Vehicle_driver_relation',
    'Owner_of_vehicle',
    'Casualty_class',
    'Type_of_collision']].corr(), annot=True) # Select the columns and calculate correlation
# Out:
# <Axes: >

# %%
# Create histogram for a target column
DF1.Accident_severity.hist()
# Out:
# <Axes: >

# %%
#Create Line plots for time
DF1.groupby('Time').Accident_severity.mean().plot()
# Out:
# <Axes: xlabel='Time'>

# %% [markdown]
# ## Feature Selection
# - Choose features that you believe will most influence the outcome based on your analysis and the insights from your visualizations. Focus on those that appear most impactful to include in your modeling.
#
# ## Train-Test Split
# * Divide the dataset into training and testing sets to evaluate the performance of your models.

# %% [markdown]
# الأعمدة اللي بستخدمها للمودلز
#
# Educational_level,Vehicle_driver_relation,Owner_of_vehicle,Casualty_class,Type_of_collision
#
# the target : Accident_severity

# %%
from sklearn.model_selection import train_test_split

features = DF1[['Educational_level', 'Vehicle_driver_relation', 'Owner_of_vehicle', 'Casualty_class', 'Type_of_collision']]
target = DF1['Accident_severity']
print(features.shape)
print(target.shape)
# Out:
# (12316, 5)
# (12316,)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %% [markdown]
# ## Modeling
#
# Once the data is split into training and testing sets, the next step is to build models to make predictions. Here, we will explore several machine learning algorithms, each with its unique characteristics and suitability for different types of data and problems. You will implement the following models:
#
# ### 1. Logistic Regression
#
# ### 2. Decision Tree Classifier
#
# ### 3. Support Vector Machine (SVM)
#
# ### 4. K-Neighbors Classifier
#
# ### Implementing the Models
# - For each model, use the training data you have prepared to train the model.

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
#Train the model
model1 = LogisticRegression()
model1.fit(X_train, y_train)
# Make predictions
y_pred = model1.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8376623376623377

# %% [markdown]
# #### Decision Tree Classifier

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
#Train the model
model2 = DecisionTreeClassifier()
model2.fit(X_train, y_train)
# Make predictions
y_pred = model2.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8303571428571429

# %% [markdown]
# #### Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC
#Train
model3 = SVC()
model3.fit(X_train, y_train)
# Make predictions
y_pred = model3.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8376623376623377

# %% [markdown]
# #### K-Neighbors Classifier

# %%
from sklearn import neighbors
#Train
model4 = neighbors.KNeighborsClassifier()
model4.fit(X_train, y_train)
# Make predictions
y_pred = model4.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.825487012987013

# %% [markdown]
# ## Model Evaluation
#
# After training your models, it's crucial to evaluate their performance to understand their effectiveness and limitations. This section outlines various techniques and metrics to assess the performance of each model you have implemented.
#
# ### Evaluation Techniques
# 1. **Confusion Matrix**
#
# 2. **Accuracy**
#
# 3. **Precision and Recall**
#
# 4. **F1 Score**
#
# 5. **ROC Curve and AUC**
#
# ### Implementing Evaluation
# - Calculate the metrics listed above using your test data.

# %%
# 1 confusion matrix to modeles
from sklearn.metrics import confusion_matrix
model1 = confusion_matrix(y_test, y_pred)
print(model1)
# Out:
# [[   0    3   34]
#  [   0    7  356]
#  [   0   37 2027]]

# %%
# 2 F1 Score
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_pred, average='weighted')
print(f1)
# Out:
# 0.7628709512914027

# %% [markdown]
# ## Project Questions:
#
# ### Comparative Analysis
#
# - **Compare Metrics**: Examine the performance metrics (such as accuracy, precision, and recall) of each model. Document your observations on which model performs best for your dataset and the problem you're addressing.
# - **Evaluate Trade-offs**: Discuss the trade-offs you encountered when choosing between models. Consider factors like computational efficiency, ease of implementation, and model interpretability.
# - **Justify Your Choice**: After comparing and evaluating, explain why you believe one model is the best choice. Provide a clear rationale based on the performance metrics and trade-offs discussed.
# - **Feature Importance**: Identify and discuss the most important features for the best-performing model. How do these features impact the predictions? Use the visualizations you have created to justify your answer if necessary.
# - **Model Limitations**: Discuss any limitations you encountered with the models you used. Are there any aspects of the data or the problem that these models do not handle well?
# - **Future Improvements**: Suggest potential improvements or further steps you could take to enhance model performance. This could include trying different algorithms, feature engineering techniques, or tuning hyperparameters.

# %% [markdown]
# ### Answer Here:
#
# 1:
# LogisticRegression and SVC had the best performance is: 83.7 for predicted Accident severity while DS and KNeighbors also had good performance but less performance
#
# 2:
# Actually I chose two model beacause its the same performance  predicted
#
# 3:
# So I prefer the Logistics as the best model it was faster in running than SVC
#
#
# 4:
# The impact can change if I use another features
#
#
# 5:
# I had limitations in  the measures and how to work with it,, with encoding
#
#
# 6:
# I suggest cleaning that dataset more and then choosing more features to predicted, also we can use it to model random forest
